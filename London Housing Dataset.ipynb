# %% [markdown]
# # London Housing Dataset
# # (A part of big data analysis)
# This dataset is primarily centered around the housing market of london. It containsa lot of additional relevant data:
#         1. Monthly average prices
#         2.Yearly number of houses sold
#         3.Monthly number of crimes committed
# The data is used here is from year 1995 to 2019 of each different areas.
# we will analyze this data using pandas dataframe.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\Sonu\Desktop\data science project\csv file\housing_in_london_monthly_variables.csv")

# %%
data
# Out:
#              date            area  average_price       code  houses_sold  \
# 0      1995-01-01  city of london          91449  E09000001         17.0
# 1      1995-02-01  city of london          82203  E09000001          7.0
# 2      1995-03-01  city of london          79121  E09000001         14.0
# 3      1995-04-01  city of london          77101  E09000001          7.0
# 4      1995-05-01  city of london          84409  E09000001         10.0
# ...           ...             ...            ...        ...          ...
# 13544  2019-09-01         england         249942  E92000001      64605.0
# 13545  2019-10-01         england         249376  E92000001      68677.0
# 13546  2019-11-01         england         248515  E92000001      67814.0
# 13547  2019-12-01         england         250410  E92000001          NaN
# 13548  2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  borough_flag
# 0               NaN             1
# ...

# %%
data.count()
# Out:
# date             13549
# area             13549
# average_price    13549
# code             13549
# houses_sold      13455
# no_of_crimes      7439
# borough_flag     13549
# dtype: int64

# %%
data.isnull().sum()
# Out:
# date                0
# area                0
# average_price       0
# code                0
# houses_sold        94
# no_of_crimes     6110
# borough_flag        0
# dtype: int64

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# # 1.Convert the datatype of 'data' column to datetime format.

# %%
data.head()
# Out:
#          date            area  average_price       code  houses_sold  \
# 0  1995-01-01  city of london          91449  E09000001         17.0
# 1  1995-02-01  city of london          82203  E09000001          7.0
# 2  1995-03-01  city of london          79121  E09000001         14.0
# 3  1995-04-01  city of london          77101  E09000001          7.0
# 4  1995-05-01  city of london          84409  E09000001         10.0
#
#    no_of_crimes  borough_flag
# 0           NaN             1
# 1           NaN             1
# 2           NaN             1
# 3           NaN             1
# 4           NaN             1

# %%
data.dtypes
# Out:
# date              object
# area              object
# average_price      int64
# code              object
# houses_sold      float64
# no_of_crimes     float64
# borough_flag       int64
# dtype: object

# %%
data.date=pd.to_datetime(data.date)

# %%
data.dtypes
# Out:
# date             datetime64[ns]
# area                     object
# average_price             int64
# code                     object
# houses_sold             float64
# no_of_crimes            float64
# borough_flag              int64
# dtype: object

# %% [markdown]
# # 2. Add a new column "year" in the dataframe , whiich contains year only.

# %%
data.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes  borough_flag
# 0           NaN             1
# 1           NaN             1

# %%
data["year"]=data.date.dt.year

# %%
data
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  borough_flag  year
# 0               NaN             1  1995
# ...

# %% [markdown]
# # 2.1 Add a new column "month" as 2nd column in the dataframe ,which contains month only.

# %%
data.insert(1,"month",data.date.dt.month)

# %%
data.head(2)
# Out:
#         date  month            area  average_price       code  houses_sold  \
# 0 1995-01-01      1  city of london          91449  E09000001         17.0
# 1 1995-02-01      2  city of london          82203  E09000001          7.0
#
#    no_of_crimes  borough_flag  year
# 0           NaN             1  1995
# 1           NaN             1  1995

# %% [markdown]
# # 3. Remove the column 'year' and 'month' from the dataframe.

# %%
 #data.drop(['month','year'], axis=1)     # it is for temporarily
# Out:
#             date            area  average_price       code  houses_sold  \
# 0     1995-01-01  city of london          91449  E09000001         17.0
# 1     1995-02-01  city of london          82203  E09000001          7.0
# 2     1995-03-01  city of london          79121  E09000001         14.0
# 3     1995-04-01  city of london          77101  E09000001          7.0
# 4     1995-05-01  city of london          84409  E09000001         10.0
# ...          ...             ...            ...        ...          ...
# 13544 2019-09-01         england         249942  E92000001      64605.0
# 13545 2019-10-01         england         249376  E92000001      68677.0
# 13546 2019-11-01         england         248515  E92000001      67814.0
# 13547 2019-12-01         england         250410  E92000001          NaN
# 13548 2020-01-01         england         247355  E92000001          NaN
#
#        no_of_crimes  borough_flag
# 0               NaN             1
# ...

# %%
data.drop(['month','year'], axis=1, inplace=True)

# %%
data.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes  borough_flag
# 0           NaN             1
# 1           NaN             1

# %% [markdown]
# # 4. show all the records where 'no. of crime' is 0.
# # And how many such records are there?

# %%
data.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes  borough_flag
# 0           NaN             1
# 1           NaN             1

# %%
len(data[data.no_of_crimes==0])
# Out:
# 104

# %% [markdown]
# # 5. what is the maximum and minimum 'average_price' per year in england?

# %%
data.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes  borough_flag
# 0           NaN             1
# 1           NaN             1

# %%
data["year"]=data.date.dt.year

# %%
data.head(2)
# Out:
#         date            area  average_price       code  houses_sold  \
# 0 1995-01-01  city of london          91449  E09000001         17.0
# 1 1995-02-01  city of london          82203  E09000001          7.0
#
#    no_of_crimes  borough_flag  year
# 0           NaN             1  1995
# 1           NaN             1  1995

# %%
df1=data[data.area=='england']
df1
# Out:
#             date     area  average_price       code  houses_sold  \
# 13248 1995-01-01  england          53203  E92000001      47639.0
# 13249 1995-02-01  england          53096  E92000001      47880.0
# 13250 1995-03-01  england          53201  E92000001      67025.0
# 13251 1995-04-01  england          53591  E92000001      56925.0
# 13252 1995-05-01  england          53678  E92000001      64192.0
# ...          ...      ...            ...        ...          ...
# 13544 2019-09-01  england         249942  E92000001      64605.0
# 13545 2019-10-01  england         249376  E92000001      68677.0
# 13546 2019-11-01  england         248515  E92000001      67814.0
# 13547 2019-12-01  england         250410  E92000001          NaN
# 13548 2020-01-01  england         247355  E92000001          NaN
#
#        no_of_crimes  borough_flag  year
# 13248           NaN             0  1995
# 13249           NaN             0  1995
# 13250           NaN             0  1995
# ...

# %%
df1.groupby('year').average_price.max()
# Out:
# year
# 1995     53901
# 1996     55755
# 1997     61564
# 1998     65743
# 1999     75071
# 2000     84191
# 2001     95992
# 2002    119982
# 2003    138985
# 2004    160330
# 2005    167244
# 2006    182031
# 2007    194764
# 2008    191750
# 2009    174136
# 2010    180807
# 2011    177335
# 2012    180129
# 2013    188544
# 2014    203639
# 2015    219582
# 2016    231922
# 2017    242628
# 2018    248620
# 2019    250410
# 2020    247355
# Name: average_price, dtype: int64

# %%
df1.groupby('year').average_price.min()
# Out:
# year
# 1995     52788
# 1996     52333
# 1997     55789
# 1998     61659
# 1999     65522
# 2000     75219
# 2001     84245
# 2002     96215
# 2003    121610
# 2004    139719
# 2005    158572
# 2006    166544
# 2007    181824
# 2008    165795
# 2009    159340
# 2010    174458
# 2011    173046
# 2012    174161
# 2013    176816
# 2014    188265
# 2015    202856
# 2016    220361
# 2017    231593
# 2018    240428
# 2019    243281
# 2020    247355
# Name: average_price, dtype: int64

# %% [markdown]
# # 6. what is the maximum and minimum 'no. of crimes'recorded per area?

# %%
data.groupby('area').no_of_crimes.max().sort_values(ascending=True)
# Out:
# area
# city of london              10.0
# kingston upon thames      1379.0
# sutton                    1425.0
# richmond upon thames      1551.0
# merton                    1623.0
# harrow                    1763.0
# bexley                    1914.0
# havering                  1956.0
# barking and dagenham      2049.0
# redbridge                 2560.0
# bromley                   2637.0
# hammersmith and fulham    2645.0
# kensington and chelsea    2778.0
# enfield                   2798.0
# lewisham                  2813.0
# hounslow                  2817.0
# hillingdon                2819.0
# greenwich                 2853.0
# barnet                    2893.0
# brent                     2937.0
# waltham forest            2941.0
# wandsworth                3051.0
# haringey                  3199.0
# croydon                   3263.0
# tower hamlets             3316.0
# islington                 3384.0
# ealing                    3401.0
# hackney                   3466.0
# ...

# %%
data.groupby('area').no_of_crimes.min().sort_values(ascending=True)
# Out:
# area
# city of london               0.0
# kingston upon thames       692.0
# richmond upon thames       700.0
# sutton                     787.0
# merton                     819.0
# bexley                     860.0
# harrow                     937.0
# havering                  1130.0
# barking and dagenham      1217.0
# hammersmith and fulham    1323.0
# kensington and chelsea    1347.0
# bromley                   1441.0
# hillingdon                1445.0
# redbridge                 1487.0
# greenwich                 1513.0
# hounslow                  1529.0
# haringey                  1536.0
# waltham forest            1575.0
# wandsworth                1582.0
# enfield                   1635.0
# tower hamlets             1646.0
# lewisham                  1675.0
# barnet                    1703.0
# brent                     1850.0
# hackney                   1870.0
# ealing                    1871.0
# islington                 1871.0
# croydon                   2031.0
# ...

# %% [markdown]
# # 7. Show the total count of records of each area, where average price is less than 100000.

# %%
data[data.average_price<100000].area.value_counts()
# Out:
# north east              112
# north west              111
# yorks and the humber    110
# east midlands            96
# west midlands            94
# england                  87
# barking and dagenham     85
# south west               78
# east of england          76
# newham                   72
# bexley                   64
# waltham forest           64
# lewisham                 62
# havering                 60
# south east               59
# greenwich                59
# croydon                  57
# enfield                  54
# sutton                   54
# hackney                  53
# redbridge                52
# southwark                48
# tower hamlets            47
# outer london             46
# hillingdon               44
# hounslow                 41
# lambeth                  41
# brent                    40
# london                   39
# merton                   35
# bromley                  33
# haringey                 33
# inner london             31
# ...
